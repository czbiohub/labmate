# %%
# %matplotlib inline

## load the extension (a function specific to jupyter)
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd 
import os.path

# use the extenion to say reload any modules every time we run the cell. Otherwise changes wont get updated. 
# %autoreload 2 

from common_code import (
    PlateChoices,
    PathTo,
    MetaData,
    MergeParams,
    convert_csv_to_df,
    import_coords_and_index
)

# %% [markdown]
# ## import_coords_and_index
# This function will take in the following parameters:
#
# 1) metadata_df= metadata from make_metadata()function above. Currently this must already be read into the notebook
#
# 2) path_to_coords= path to the folder containing the 96 to 384 coordinate conversation
#
# 3) path_to_i7_384 = path to folder containing i7_indexes from 384 well plate
#
# 4) path_to_i5_384 = path to folder containing the i5_indexes from 384 well plate
#
# 5) i7_384_coord = coordinate from your i7 384 well plate you want to draw from
#
# 6) i7_keyname = name of csv for the particular i7 index plate you are using
#
# 7) i5_384_coord = coordinate from your i5 384 well plate you want to draw from
#
# 8) i5_keyname = name of csv for the particular i5 index plate you are using
#
# 9) well_type = default is "well_id_96"
#
# 10) path_to_data=path to folder where you will store your final table
#
# 11) date= date to be appended to your final sheet
#
# 12) name= name of the final file, defaul is "metadata_indexes"

# %%
## define paths and index selections and get metadata
data_paths_20180607 = PathTo()
chosen_indices_20180607 = PlateChoices("i7_index_384", "coord1_384", "i5_index_384", "coord1_384")
meta_data_20180607 = MetaData("20180529_metadata.csv")
merge_params_20180607 = MergeParams(index_merge_id="well_id_384", plate_merge_id="well_id_96")

# %%
experiment=import_coords_and_index(metadata_df = meta_data_20180607.make_df(),
                            data_paths = data_paths_20180607,
                            chosen_indices = chosen_indices_20180607,
                            plate_merge_params = merge_params_20180607, 
                            date = "20180607", 
                            saved_csv_name="metadata_with_indices")
list(experiment.columns)
# Out:
# ['well_id_96',
#  'coord1_384_x',
#  'well_id_384_x',
#  'I7_Index_ID',
#  'i7_index_sequence',
#  'cell_number',
#  'experimental_or_control',
#  'nuclease',
#  'nucleofection_buffer',
#  'coord1_384_y',
#  'well_id_384_y',
#  'i5_index_ID',
#  'i5_index_sequence']

# %%
guides_ordered=pd.read_csv("../practice/guide_seq_tidy.csv")
guides_ordered
experiment_and_guides=experiment.merge(guides_ordered, on="well_id_96")
guides_ordered
# Out:
#    well_id_96 guide plate name   guide_description        guide_sequence
# 0          A1         oGEp12_01  vanOverbeek2016_01  GCTGATGTAGTCACTCTTGA
# 1          A2         oGEp12_02  vanOverbeek2016_02  AGTGTGCATTGCCACCTCAG
# 2          A3         oGEp12_03  vanOverbeek2016_03  AGATGCAGGCTGCAGATGCC
# 3          A4         oGEp12_04  vanOverbeek2016_04  GGCCCTCGGCGGCGGCTCCC
# 4          A5         oGEp12_05  vanOverbeek2016_05  ACAGAACATGTTGTTATAGA
# 5          A6         oGEp12_06  vanOverbeek2016_06  ACAGATTCTGGAAAGCTCCT
# 6          A7         oGEp12_07  vanOverbeek2016_07  GGTCAACAAGTGGAACTCTA
# 7          A8         oGEp12_08  vanOverbeek2016_08  GGAGTATTTCAGGGGCTCTT
# 8          A9         oGEp12_09  vanOverbeek2016_09  GGGAGGGCTGTGCTGCTAGT
# 9         A10         oGEp12_10  vanOverbeek2016_10  GCAACTTGAAATTATATCTG
# 81        G10         oGEp12_82  vanOverbeek2016_82  CGGCCAGAGACCGAGCCCTA
# 82        G11         oGEp12_83  vanOverbeek2016_83  GTTGTGGCAGCAGTCACTGG
# 83        G12         oGEp12_84  vanOverbeek2016_84  GGCCACTGTAGTCCTCCAGG
# 84         H1         oGEp12_85  vanOverbeek2016_85  GGAGCCAGCCCCTGGCCTTC
# 85         H2         oGEp12_86  vanOverbeek2016_86  TCCCAAAGGCGGAGGGCGTT
# 86         H3         oGEp12_87  vanOverbeek2016_87  TGAGTCCGAGCAGAAGAAGA
# 87         H4         oGEp12_88  vanOverbeek2016_88  GAGTCCGAGCAGAAGAAGAA
# 88         H5         oGEp12_89  vanOverbeek2016_89  GGCAGCCAGCATGATGAGAC
# 89         H6         oGEp12_90  vanOverbeek2016_90  CTTCTTTGCTTGTTCAAATG
# 90         H7         oGEp12_91  vanOverbeek2016_91  GCAGGGTGAGTGTCTCAGCC
# 91         H8         oGEp12_92  vanOverbeek2016_92  GAACTGTGTGTGTTGCAGGG
# 92         H9         oGEp12_93  vanOverbeek2016_93  GGGCTGAGAGAGGGACAAGT
# 93        H10         oGEp12_94  vanOverbeek2016_94  AAAACGTTTCCAAGACATGA
# 94        H11         oGEp12_95  vanOverbeek2016_95  CCACGCCCGCGGGGTGAAGT
# 95        H12         oGEp12_96  vanOverbeek2016_96  GAGCCCTCAGGCGAACCTCT
#
# [96 rows x 4 columns]

# %%
orientations = []
ordered_guides = []

for idx, seq in enumerate(data_frame["seq"]):
    if seq[:-2] == "GG":
        orientations.append("F")
        ordered_guides.append(seq[:-2])
    else: 
        orientations.append("R")
        ordered_guides.append(reverse_complement(seq)[:-2])
        
data_frame["orientations"] = orientations
data_frame["ordered_guides"] = ordered_guides
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-ef5a044e809d> in <module>()
#       2 ordered_guides = []
#       3
# ----> 4 for idx, seq in enumerate(data_frame["seq"]):
#       5     if seq[:-2] == "GG":
#       6         orientations.append("F")
#
# NameError: name 'data_frame' is not defined

# %%
orientation = []
ref_oriented_guide = []

for idx, seq in enumerate(data_frame["seq"]):
    if seq in df_with_pams["seq"]:
        orientations.append("F")
        ref_oriented_guide = seq
    elif reverse_complement(seq) in df_with_pams["seq"]: 
        orientations.append("R")
        ref_oriented_guide = reverse_complement(seq)
    else:
        raise RuntimeError("Missing guide: {}".format(seq))
        
data_frame["orientations"] = orientations
data_frame["ref_oriented_guide"] = ref_oriented_guide

# %% [markdown]
# ### Convert your work to a python script.
#
# `! jupyter nbconvert --to script [yournotebookname].ipynb`

# %%
! jupyter nbconvert --to script 20180605_Giana_Aaron_labmate_96totidy_addindex.ipynb
# Out:
# [NbConvertApp] Converting notebook 20180605_Giana_Aaron_labmate_96totidy_addindex.ipynb to script
# [NbConvertApp] Writing 4504 bytes to 20180605_Giana_Aaron_labmate_96totidy_addindex.py

# %%
regular_meta_data_files = ["a.csv", "b.csv", "c.csv"]
weird_metadata_files = ["e.csv", "f.csv", "g.csv"]


all_metadata = [MetaData(e) for e in regular_meta_data_files] +
               [DataFrameToCsvMetaData(e) for e in weird_metadata_files]
    
metadata_dfs = [md.make_df() for md in all_metadata]

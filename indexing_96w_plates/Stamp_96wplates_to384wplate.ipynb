# %%
import pandas as pd 
# %matplotlib inline
import glob
import os.path

# %% [markdown]
# ## import_coords_and_index
# This function will take in the following parameters:
#
# 1) metadata_df= metadata from make_metadata()function above. Currently this must already be read into the notebook
#
# 2) path_to_coords= path to the folder containing the 96 to 384 coordinate conversation
#
# 3) path_to_i7_384 = path to folder containing i7_indexes from 384 well plate
#
# 4) path_to_i5_384 = path to folder containing the i5_indexes from 384 well plate
#
# 5) i7_384_coord = coordinate from your i7 384 well plate you want to draw from
#
# 6) i7_keyname = name of csv for the particular i7 index plate you are using
#
# 7) i5_384_coord = coordinate from your i5 384 well plate you want to draw from
#
# 8) i5_keyname = name of csv for the particular i5 index plate you are using
#
# 9) well_type = default is "well_id_96"
#
# 10) path_to_data=path to folder where you will store your final table
#
# 11) date= date to be appended to your final sheet
#
# 12) name= name of the final file, defaul is "metadata_indexes"

# %%
## make classes for accessing paths, metadat and indices

class MetaData:
    RETURNED_DATA="returned_data"
    
    def __init__(self, metadata_csv):
        self.path = "{a}/{b}".format(a=MetaData.RETURNED_DATA, b=metadata_csv)
        self.name = os.path.splitext(metadata_csv)[0]
    def make_df(self):
        return pd.read_csv(self.path).drop("Unnamed: 0", axis=1)
    def col_names(self):
        return pd.read_csv(self.path).columns

class PathTo: 
    COORD_CONVS='coordinate_conversion_maps'
    i7_INDEXES='i7_indexes_plates'
    i5_INDEXES='i5_indexes_plates'
    RETURNED_DATA="returned_data"
    

def convert_csv_to_df(path_to_data):
    all_data=glob.glob("{}/*.csv".format(path_to_data))
    
    dict_of_all_data={}

    for file in all_data:
        file_name=os.path.splitext(os.path.basename(file))[0]
        df=pd.read_csv(file)
        dict_of_all_data[file_name]=df
    return dict_of_all_data

# %%
meta_data_20180607 = MetaData("20180529_metadata.csv")
data_paths_20180607 = PathTo()
dict_of_coords = convert_csv_to_df(data_paths_20180607.COORD_CONVS)
dict_of_i5=convert_csv_to_df(data_paths_20180607.i5_INDEXES)
dict_of_i7=convert_csv_to_df(data_paths_20180607.i7_INDEXES)
dict_of_coords["coord4_384"]
dict_of_i7["i7_index_384"]
dict_of_i5["i5_index_384"]
# Out:
#     well_id_384 i5_index_ID i5_index_sequence
# 0            A1    i5-00001          ACGATCAG
# 1            A2    i5-00002          TCGAGAGT
# 2            A3    i5-00003          CTAGCTCA
# 3            A4    i5-00004          ATCGTCTC
# 4            A5    i5-00005          TCGACAAG
# 5            A6    i5-00006          CCTTGGAA
# 6            A7    i5-00049          ATCATGCG
# 7            A8    i5-00008          TGTTCCGT
# 8            A9    i5-00009          ATTAGCCG
# 9           A10    i5-00010          CGATCGAT
# 10          A11    i5-00011          GATCTTGC
# 11          A12    i5-00012          AGGATAGC
# 12          A13    i5-00013          GTAGCGTA
# 13          A14    i5-00014          AGAGTCCA
# 14          A15    i5-00015          GCTACTCT
# 15          A16    i5-00016          CTCTGGAT
# 16          A17    i5-00017          AGATCGTC
# 17          A18    i5-00018          GCTCAGTT
# 18          A19    i5-00019          GTCCTAAG
# ...

# %%
## trying to change wel id from A1 to A01 values for better sorting. 
## Can't seem to make this work for actually replacing the values directly in the data frame.  

list1=[]

for idx,val in enumerate(dict_of_i5["i5_index_384"]["well_id_384"]):
        new_val=dict_of_i5["i5_index_384"]["well_id_384"][idx].replace(val, val+" ")
        list1.append(new_val)


for idx,val in enumerate(list1):
    if val[2]==" ":
        list1[idx]=val.replace(val[1], "0"+val[1]).replace(" ","")

     
dflist1=pd.DataFrame(list1)
dflist1.to_csv("/Users/giana.cirolia/Desktop/file.csv")


#for idx,val in enumerate(dict_of_i5["i5_index_384"]["well_id_384"]):
#    if len(val)==2:
#        dict_of_i5["i5_index_384"]["well_id_384"][idx]=val.replace(val[1],"0"+val[1])

#dict_of_i5["i5_index_384"]["well_id_384"]

# %%
for idx,val in enumerate(dict_of_i5["i5_index_384"]["well_id_384"]):
    if len(val)==2:
        dict_of_i5["i5_index_384"]["well_id_384"][idx]=val.replace(val[1],"0"+val[1])

dict_of_i5["i5_index_384"]["well_id_384"]
# Out:
# 0      A01
# 1      A02
# 2      A03
# 3      A04
# 4      A05
# 5      A06
# 6      A07
# 7      A08
# 8      A09
# 9      A10
# 10     A11
# 11     A12
# 12     A13
# 13     A14
# 14     A15
# 15     A16
# 16     A17
# 17     A18
# 18     A19
# 19     A20
# 20     A21
# 21     A22
# 22     A23
# 23     A24
# 24     B01
# 25     B02
# 26     B03
# 27     B04
# 28     B05
# 29     B06
#       ...
# 354    O19
# 355    O20
# 356    O21
# 357    O22
# 358    O23
# 359    O24
# 360    P01
# 361    P02
# 362    P03
# 363    P04
# 364    P05
# 365    P06
# 366    P07
# 367    P08
# 368    P09
# 369    P10
# 370    P11
# 371    P12
# 372    P13
# 373    P14
# 374    P15
# 375    P16
# 376    P17
# 377    P18
# 378    P19
# 379    P20
# 380    P21
# 381    P22
# 382    P23
# 383    P24
# Name: well_id_384, Length: 384, dtype: object

# %%
for idx,val in enumerate(dict_of_i5["i5_index_384"]["well_id_384"]):
        dict_of_i5["i5_index_384"]["well_id_384"][idx]= val[0] + ("%02d" % int(val[1:]))

dict_of_i5["i5_index_384"]["well_id_384"]
# Out:
# 0      A01
# 1      A02
# 2      A03
# 3      A04
# 4      A05
# 5      A06
# 6      A07
# 7      A08
# 8      A09
# 9      A10
# 10     A11
# 11     A12
# 12     A13
# 13     A14
# 14     A15
# 15     A16
# 16     A17
# 17     A18
# 18     A19
# 19     A20
# 20     A21
# 21     A22
# 22     A23
# 23     A24
# 24     B01
# 25     B02
# 26     B03
# 27     B04
# 28     B05
# 29     B06
#       ...
# 354    O19
# 355    O20
# 356    O21
# 357    O22
# 358    O23
# 359    O24
# 360    P01
# 361    P02
# 362    P03
# 363    P04
# 364    P05
# 365    P06
# 366    P07
# 367    P08
# 368    P09
# 369    P10
# 370    P11
# 371    P12
# 372    P13
# 373    P14
# 374    P15
# 375    P16
# 376    P17
# 377    P18
# 378    P19
# 379    P20
# 380    P21
# 381    P22
# 382    P23
# 383    P24
# Name: well_id_384, Length: 384, dtype: object

# %%
a = pd.DataFrame({"seq": ["AACC","CCTT"]})
b = pd.DataFrame({"seq": ["CCTTGG","AACCGG"], "name": ["b","a"]})

b["seq_without_pam"] = [e[:-2] for e in b["seq"]]

a.merge(b, left_on="seq", right_on="seq_without_pam")
# Out:
#   seq_x name   seq_y seq_without_pam
# 0  AACC    a  AACCGG            AACC
# 1  CCTT    b  CCTTGG            CCTT

# %%
type(dict_of_i5["i5_index_384"]["well_id_384"])
# Out:
# pandas.core.series.Series

# %%
meta_data_20180607_df_plate1=meta_data_20180607.make_df()
meta_data_20180607_df_plate2=meta_data_20180607.make_df()
meta_data_20180607_df_plate3=meta_data_20180607.make_df()
meta_data_20180607_df_plate4=meta_data_20180607.make_df()

# %%
meta_data_20180607_df_plate1["plate"]="plate_1"
meta_data_20180607_df_plate2["plate"]="plate_2"
meta_data_20180607_df_plate3["plate"]="plate_3"
meta_data_20180607_df_plate4["plate"]="plate_4"

# %%
plate1=meta_data_20180607_df_plate1.merge(dict_of_coords["coord1_384"], on = 'well_id_96')
plate2=meta_data_20180607_df_plate2.merge(dict_of_coords["coord2_384"], on = 'well_id_96')
plate3=meta_data_20180607_df_plate3.merge(dict_of_coords["coord3_384"], on = 'well_id_96')
plate4=meta_data_20180607_df_plate4.merge(dict_of_coords["coord4_384"], on = 'well_id_96')
plate1_rename=plate1.rename(columns={'coord1_384':"coord"})
plate2_rename=plate2.rename(columns={'coord2_384':"coord"})
plate3_rename=plate3.rename(columns={'coord3_384':"coord"})
plate4_rename=plate4.rename(columns={'coord4_384':"coord"})
plate1_rename
# Out:
#     cell_number well_id_96 experimental_or_control nuclease  \
# 0       1000000         A1                     exp   spCas9
# 1       1000000         B1                     exp   spCas9
# 2       1000000         C1                     exp   spCas9
# 3       1000000         D1                     exp   spCas9
# 4       1000000         E1                     exp   spCas9
# 5       1000000         F1                     exp   spCas9
# 6       1000000         G1                     exp   spCas9
# 7       1000000         H1                     exp   spCas9
# 8       1000000         A2                     exp   spCas9
# 9       1000000         B2                     exp   spCas9
# 10      1000000         C2                     exp   spCas9
# 11      1000000         D2                     exp   spCas9
# 12      1000000         E2                     exp   spCas9
# 13      1000000         F2                     exp   spCas9
# 14      1000000         G2                     exp   spCas9
# ...

# %%
allplates=plate1_rename.append(plate2_rename).append(plate3_rename).append(plate4_rename)
allplates.head()
all_plates_wi7=allplates.merge(dict_of_i7["i7_index_384"], left_on="coord", right_on="well_id_384")
all_plates_wi7i5=all_plates_wi7.merge(dict_of_i5["i5_index_384"], left_on="coord", right_on="well_id_384")
all_plates_wi7i5
# Out:
#      cell_number well_id_96 experimental_or_control nuclease  \
# 0        1000000         A1                     exp   spCas9
# 1        1000000         B1                     exp   spCas9
# 2        1000000         C1                     exp   spCas9
# 3        1000000         D1                     exp   spCas9
# 4        1000000         E1                     exp   spCas9
# 5        1000000         F1                     exp   spCas9
# 6        1000000         G1                     exp   spCas9
# 7        1000000         H1                     exp   spCas9
# 8        1000000         A2                     exp   spCas9
# 9        1000000         B2                     exp   spCas9
# 10       1000000         C2                     exp   spCas9
# 11       1000000         D2                     exp   spCas9
# 12       1000000         E2                     exp   spCas9
# 13       1000000         F2                     exp   spCas9
# ...

# %%
## make classes for accessing paths, metadat and indices

class MetaData:
    RETURNED_DATA="returned_data"
    
    def __init__(self, metadata_csv):
        self.path = "{a}/{b}".format(a=MetaData.RETURNED_DATA, b=metadata_csv)
        self.name = os.path.splitext(metadata_csv)[0]
    def make_df(self):
        return pd.read_csv(self.path).drop("Unnamed: 0", axis=1)
    def col_names(self):
        return pd.read_csv(self.path).columns  
    
class PathTo: 
    COORD_CONVS='coordinate_conversion_maps'
    i7_INDEXES='i7_indexes_plates'
    i5_INDEXES='i5_indexes_plates'
    RETURNED_DATA="returned_data"

class PlateChoices: 
    def __init__(self, i7_plate_name, i7_chosen_coord, i5_plate_name, i5_chosen_coord):
        self.i7_plate_name = i7_plate_name
        self.i5_plate_name = i5_plate_name
        self.i7_chosen_coord = i7_chosen_coord
        self.i5_chosen_coord = i5_chosen_coord
        self.merge_384w = "well_id_384"
        self.merge_96w = "well_id_96"
        
class MergeParams:
    def __init__(self, index_merge_value, plate_merge_value):
        self.index_merge_id = index_merge_value 
        self.plate_merge_id = plate_merge_value

# %%
## define paths and index selections and get metadata
data_paths_20180607 = PathTo()
chosen_indices_20180607 = IndexPlateChoices("i7_index_384", "coord1_384", "i5_index_384", "coord1_384")
meta_data_20180607 = MetaData("20180529_metadata.csv")
merge_params_20180607 = MergeParams(index_merge_value="well_id_384", plate_merge_value="well_id_96")

# %%
def convert_csv_to_df(path_to_data):
    all_data=glob.glob("{}/*.csv".format(path_to_data))
    
    dict_of_all_data={}

    for file in all_data:
        file_name=os.path.splitext(os.path.basename(file))[0]
        df=pd.read_csv(file)
        dict_of_all_data[file_name]=df
    return dict_of_all_data

def import_coords_and_index(metadata_df,
                            data_paths,
                            chosen_indices,
                            plate_merge_well_type, 
                            date, 
                            saved_csv_name="metadata_w_indexes"):
    
    dict_i7_indices = convert_csv_to_df(data_paths.i7_INDEXES) ## could also so PathTo.i7_INDEXES bc all constants ( cool)
    dict_i5_indices = convert_csv_to_df(data_paths.i5_INDEXES)
    dict_of_coords = convert_csv_to_df(data_paths.COORD_CONVS)
    
    
    i7_selected_indices=dict_of_coords[chosen_indices.i7_chosen_coord].merge(dict_i7_indices[chosen_indices.i7_plate_name],left_on=chosen_indices.i7_chosen_coord, right_on=merge_params_20180607.index_merge_id)
    i5_selected_indices=dict_of_coords[chosen_indices.i5_chosen_coord].merge(dict_i5_indices[chosen_indices.i5_plate_name],left_on=chosen_indices.i5_chosen_coord, right_on=merge_params_20180607.index_merge_id)
    i7_metadata_merged=i7_selected_indices.merge(metadata_df, on=plate_merge_well_type)
    i5_i7_metadata_merged=i7_metadata_merged.merge(i5_selected_indices,on=plate_merge_well_type)
    
    i5_i7_metadata_merged.to_csv("{a}/{b}_{c}.csv".format(a=data_paths.RETURNED_DATA, b=date, c=saved_csv_name))
    return i5_i7_metadata_merged
    
experiment=import_coords_and_index(metadata_df = meta_data_20180607.make_df(),
                            data_paths = data_paths_20180607,
                            chosen_indices = chosen_indices_20180607,
                            plate_merge_well_type = merge_params_20180607.plate_merge_id, 
                            date = "20180607", 
                            saved_csv_name="metadata_with_indices")
list(experiment.columns)
# Out:
# ['well_id_96',
#  'coord1_384_x',
#  'well_id_384_x',
#  'I7_Index_ID',
#  'i7_index_sequence',
#  'cell_number',
#  'experimental_or_control',
#  'nuclease',
#  'nucleofection_buffer',
#  'coord1_384_y',
#  'well_id_384_y',
#  'i5_index_ID',
#  'i5_index_sequence']

# %%
guides_ordered=pd.read_csv("guide_seq_tidy.csv")
guides_ordered
experiment_and_guides=experiment.merge(guides, on="well_id_96")
guides_ordered
# Out:
#    well_id_96 guide plate name   guide_description        guide_sequence
# 0          A1         oGEp12_01  vanOverbeek2016_01  GCTGATGTAGTCACTCTTGA
# 1          A2         oGEp12_02  vanOverbeek2016_02  AGTGTGCATTGCCACCTCAG
# 2          A3         oGEp12_03  vanOverbeek2016_03  AGATGCAGGCTGCAGATGCC
# 3          A4         oGEp12_04  vanOverbeek2016_04  GGCCCTCGGCGGCGGCTCCC
# 4          A5         oGEp12_05  vanOverbeek2016_05  ACAGAACATGTTGTTATAGA
# 5          A6         oGEp12_06  vanOverbeek2016_06  ACAGATTCTGGAAAGCTCCT
# 6          A7         oGEp12_07  vanOverbeek2016_07  GGTCAACAAGTGGAACTCTA
# 7          A8         oGEp12_08  vanOverbeek2016_08  GGAGTATTTCAGGGGCTCTT
# 8          A9         oGEp12_09  vanOverbeek2016_09  GGGAGGGCTGTGCTGCTAGT
# 9         A10         oGEp12_10  vanOverbeek2016_10  GCAACTTGAAATTATATCTG
# 10        A11         oGEp12_11  vanOverbeek2016_11  GTAGAGAAAGAAGCAGTGCC
# 11        A12         oGEp12_12  vanOverbeek2016_12  ATAGGAGAAGATGATGTATA
# ...

# %% [markdown]
# ### Convert your work to a python script.
#
# `! jupyter nbconvert --to script [yournotebookname].ipynb`

# %%
! jupyter nbconvert --to script 20180605_Giana_Aaron_labmate_96totidy_addindex.ipynb
# Out:
# [NbConvertApp] Converting notebook 20180605_Giana_Aaron_labmate_96totidy_addindex.ipynb to script
# [NbConvertApp] Writing 4504 bytes to 20180605_Giana_Aaron_labmate_96totidy_addindex.py

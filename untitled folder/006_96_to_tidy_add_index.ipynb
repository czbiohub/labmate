# %%
import catheat
import numpy as np
import pandas as pd 
from functools import reduce 

# %matplotlib inline
import glob
import os.path

# %%
path_to_plates="/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/plate_csv"
path_to_plates
# Out:
# '/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/plate_csv'

# %%
all_csv=glob.glob("{}/*.csv".format(path_to_plates))
all_csv
# Out:
# ['/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/plate_csv/cell_number.csv',
#  '/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/plate_csv/lonza_nucleofection_buffer.csv']

# %%
dict_of_dfs={}

for file in all_csv:
        file_name=os.path.splitext(os.path.basename(file))[0] # split based on extension
        df=pd.read_csv(file)
        dict_of_dfs[file_name]=df
dict_of_dfs
# Out:
# {'cell_number':   row_letter        1        2        3        4        5        6        7  \
#  0          A  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#  1          B  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#  2          C  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#  3          D  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#  4          E  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#  5          F  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#  6          G  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#  7          H  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#
#           8        9       10       11       12
#  0  1000000  1000000  1000000  1000000  1000000
#  1  1000000  1000000  1000000  1000000  1000000
#  2  1000000  1000000  1000000  1000000  1000000
#  3  1000000  1000000  1000000  1000000  1000000
#  4  1000000  1000000  1000000  1000000  1000000
#  5  1000000  1000000  1000000  1000000  1000000
#  6  1000000  1000000  1000000  1000000  1000000
#  7  1000000  1000000  1000000  1000000  1000000  ,
#  'lonza_nucleofection_buffer':   row_letter          1          2          3          4          5  \
#  0          A  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P2
#  1          B  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P2
#  2          C  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P2
#  3          D  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P2
#  4          E  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P2
#  5          F  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P2
#  6          G  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P2
#  7          H  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P1  Buffer_P2
#
#             6          7          8          9         10         11         12
#  0  Buffer_P2  Buffer_P2  Buffer_P2  Buffer_P3  Buffer_P3  Buffer_P3  Buffer_P3
#  1  Buffer_P2  Buffer_P2  Buffer_P2  Buffer_P3  Buffer_P3  Buffer_P3  Buffer_P3
#  2  Buffer_P2  Buffer_P2  Buffer_P2  Buffer_P3  Buffer_P3  Buffer_P3  Buffer_P3
#  3  Buffer_P2  Buffer_P2  Buffer_P2  Buffer_P3  Buffer_P3  Buffer_P3  Buffer_P3
#  4  Buffer_P2  Buffer_P2  Buffer_P2  Buffer_P3  Buffer_P3  Buffer_P3  Buffer_P3
#  5  Buffer_P2  Buffer_P2  Buffer_P2  Buffer_P3  Buffer_P3  Buffer_P3  Buffer_P3
#  6  Buffer_P2  Buffer_P2  Buffer_P2  Buffer_P3  Buffer_P3  Buffer_P3  Buffer_P3
#  7  Buffer_P2  Buffer_P2  Buffer_P2  Buffer_P3  Buffer_P3  Buffer_P3  Buffer_P3  }

# %%
def remove_cols(df):
    ### define a function that will drop unwanted columns from your df along the column axis
    cols_to_drop = ['row_letter', 'col_num'] 
    removed_cols = df.drop(cols_to_drop, axis=1)
    return removed_cols

tidy_files={} ## set and empty dictionary to which we will add key value pairs, your file name and the long format of a given 96 well plate
for file_name, data_frame in dict_of_dfs.items():
    df=pd.melt(data_frame, id_vars='row_letter', var_name='col_num', value_name=file_name) # turn 96 well format into long format, returning a df with a list of values for each well in your 96 well plate.  
    df["well_id_96"]=df['row_letter'] + df['col_num'] # make a new column to combine row letter with col number. 
    tidy_files[file_name]= df # pass the df into the remove cols function to remove col for row letter and col number and add to dictionary with asoociated file name. 

tidy_files
# Out:
# {'cell_number':    row_letter col_num  cell_number well_id_96
#  0           A       1      1000000         A1
#  1           B       1      1000000         B1
#  2           C       1      1000000         C1
#  3           D       1      1000000         D1
#  4           E       1      1000000         E1
#  5           F       1      1000000         F1
#  6           G       1      1000000         G1
#  7           H       1      1000000         H1
#  8           A       2      1000000         A2
#  9           B       2      1000000         B2
#  10          C       2      1000000         C2
#  11          D       2      1000000         D2
#  12          E       2      1000000         E2
#  13          F       2      1000000         F2
#  14          G       2      1000000         G2
#  15          H       2      1000000         H2
#  16          A       3      1000000         A3
#  17          B       3      1000000         B3
#  18          C       3      1000000         C3
#  19          D       3      1000000         D3
#  20          E       3      1000000         E3
#  21          F       3      1000000         F3
#  22          G       3      1000000         G3
#  23          H       3      1000000         H3
#  24          A       4      1000000         A4
#  25          B       4      1000000         B4
#  26          C       4      1000000         C4
#  27          D       4      1000000         D4
#  28          E       4      1000000         E4
#  29          F       4      1000000         F4
#  ..        ...     ...          ...        ...
#  66          C       9      1000000         C9
#  67          D       9      1000000         D9
#  68          E       9      1000000         E9
#  69          F       9      1000000         F9
#  70          G       9      1000000         G9
#  71          H       9      1000000         H9
#  72          A      10      1000000        A10
#  73          B      10      1000000        B10
#  74          C      10      1000000        C10
#  75          D      10      1000000        D10
#  76          E      10      1000000        E10
#  77          F      10      1000000        F10
#  78          G      10      1000000        G10
#  79          H      10      1000000        H10
#  80          A      11      1000000        A11
#  81          B      11      1000000        B11
#  82          C      11      1000000        C11
#  83          D      11      1000000        D11
#  84          E      11      1000000        E11
#  85          F      11      1000000        F11
#  86          G      11      1000000        G11
#  87          H      11      1000000        H11
#  88          A      12      1000000        A12
#  89          B      12      1000000        B12
#  90          C      12      1000000        C12
#  91          D      12      1000000        D12
#  92          E      12      1000000        E12
#  93          F      12      1000000        F12
#  94          G      12      1000000        G12
#  95          H      12      1000000        H12
#
#  [96 rows x 4 columns],
#  'lonza_nucleofection_buffer':    row_letter col_num lonza_nucleofection_buffer well_id_96
#  0           A       1                  Buffer_P1         A1
#  1           B       1                  Buffer_P1         B1
#  2           C       1                  Buffer_P1         C1
#  3           D       1                  Buffer_P1         D1
#  4           E       1                  Buffer_P1         E1
#  5           F       1                  Buffer_P1         F1
#  6           G       1                  Buffer_P1         G1
#  7           H       1                  Buffer_P1         H1
#  8           A       2                  Buffer_P1         A2
#  9           B       2                  Buffer_P1         B2
#  10          C       2                  Buffer_P1         C2
#  11          D       2                  Buffer_P1         D2
#  12          E       2                  Buffer_P1         E2
#  13          F       2                  Buffer_P1         F2
#  14          G       2                  Buffer_P1         G2
#  15          H       2                  Buffer_P1         H2
#  16          A       3                  Buffer_P1         A3
#  17          B       3                  Buffer_P1         B3
#  18          C       3                  Buffer_P1         C3
#  19          D       3                  Buffer_P1         D3
#  20          E       3                  Buffer_P1         E3
#  21          F       3                  Buffer_P1         F3
#  22          G       3                  Buffer_P1         G3
#  23          H       3                  Buffer_P1         H3
#  24          A       4                  Buffer_P1         A4
#  25          B       4                  Buffer_P1         B4
#  26          C       4                  Buffer_P1         C4
#  27          D       4                  Buffer_P1         D4
#  28          E       4                  Buffer_P1         E4
#  29          F       4                  Buffer_P1         F4
#  ..        ...     ...                        ...        ...
#  66          C       9                  Buffer_P3         C9
#  67          D       9                  Buffer_P3         D9
#  68          E       9                  Buffer_P3         E9
#  69          F       9                  Buffer_P3         F9
#  70          G       9                  Buffer_P3         G9
#  71          H       9                  Buffer_P3         H9
#  72          A      10                  Buffer_P3        A10
#  73          B      10                  Buffer_P3        B10
#  74          C      10                  Buffer_P3        C10
#  75          D      10                  Buffer_P3        D10
#  76          E      10                  Buffer_P3        E10
#  77          F      10                  Buffer_P3        F10
#  78          G      10                  Buffer_P3        G10
#  79          H      10                  Buffer_P3        H10
#  80          A      11                  Buffer_P3        A11
#  81          B      11                  Buffer_P3        B11
#  82          C      11                  Buffer_P3        C11
#  83          D      11                  Buffer_P3        D11
#  84          E      11                  Buffer_P3        E11
#  85          F      11                  Buffer_P3        F11
#  86          G      11                  Buffer_P3        G11
#  87          H      11                  Buffer_P3        H11
#  88          A      12                  Buffer_P3        A12
#  89          B      12                  Buffer_P3        B12
#  90          C      12                  Buffer_P3        C12
#  91          D      12                  Buffer_P3        D12
#  92          E      12                  Buffer_P3        E12
#  93          F      12                  Buffer_P3        F12
#  94          G      12                  Buffer_P3        G12
#  95          H      12                  Buffer_P3        H12
#
#  [96 rows x 4 columns]}

# %%
def remove_cols(df):
    ### define a function that will drop unwanted columns from your df along the column axis
    cols_to_drop = ['row_letter', 'col_num'] 
    removed_cols = df.drop(cols_to_drop, axis=1)
    return removed_cols

tidy_files={} ## set and empty dictionary to which we will add key value pairs, your file name and the long format of a given 96 well plate
for file_name, data_frame in dict_of_dfs.items():
    df=pd.melt(data_frame, id_vars='row_letter', var_name='col_num', value_name=file_name) # turn 96 well format into long format, returning a df with a list of values for each well in your 96 well plate.  
    df["well_id_96"]=df['row_letter'] + df['col_num'] # make a new column to combine row letter with col number. 
    tidy_files[file_name]= remove_cols(df) # pass the df into the remove cols function to remove col for row letter and col number and add to dictionary with asoociated file name. 

tidy_files
# Out:
# {'cell_number':     cell_number well_id_96
#  0       1000000         A1
#  1       1000000         B1
#  2       1000000         C1
#  3       1000000         D1
#  4       1000000         E1
#  5       1000000         F1
#  6       1000000         G1
#  7       1000000         H1
#  8       1000000         A2
#  9       1000000         B2
#  10      1000000         C2
#  11      1000000         D2
#  12      1000000         E2
#  13      1000000         F2
#  14      1000000         G2
#  15      1000000         H2
#  16      1000000         A3
#  17      1000000         B3
#  18      1000000         C3
#  19      1000000         D3
#  20      1000000         E3
#  21      1000000         F3
#  22      1000000         G3
#  23      1000000         H3
#  24      1000000         A4
#  25      1000000         B4
#  26      1000000         C4
#  27      1000000         D4
#  28      1000000         E4
#  29      1000000         F4
#  ..          ...        ...
#  66      1000000         C9
#  67      1000000         D9
#  68      1000000         E9
#  69      1000000         F9
#  70      1000000         G9
#  71      1000000         H9
#  72      1000000        A10
#  73      1000000        B10
#  74      1000000        C10
#  75      1000000        D10
#  76      1000000        E10
#  77      1000000        F10
#  78      1000000        G10
#  79      1000000        H10
#  80      1000000        A11
#  81      1000000        B11
#  82      1000000        C11
#  83      1000000        D11
#  84      1000000        E11
#  85      1000000        F11
#  86      1000000        G11
#  87      1000000        H11
#  88      1000000        A12
#  89      1000000        B12
#  90      1000000        C12
#  91      1000000        D12
#  92      1000000        E12
#  93      1000000        F12
#  94      1000000        G12
#  95      1000000        H12
#
#  [96 rows x 2 columns],
#  'lonza_nucleofection_buffer':    lonza_nucleofection_buffer well_id_96
#  0                   Buffer_P1         A1
#  1                   Buffer_P1         B1
#  2                   Buffer_P1         C1
#  3                   Buffer_P1         D1
#  4                   Buffer_P1         E1
#  5                   Buffer_P1         F1
#  6                   Buffer_P1         G1
#  7                   Buffer_P1         H1
#  8                   Buffer_P1         A2
#  9                   Buffer_P1         B2
#  10                  Buffer_P1         C2
#  11                  Buffer_P1         D2
#  12                  Buffer_P1         E2
#  13                  Buffer_P1         F2
#  14                  Buffer_P1         G2
#  15                  Buffer_P1         H2
#  16                  Buffer_P1         A3
#  17                  Buffer_P1         B3
#  18                  Buffer_P1         C3
#  19                  Buffer_P1         D3
#  20                  Buffer_P1         E3
#  21                  Buffer_P1         F3
#  22                  Buffer_P1         G3
#  23                  Buffer_P1         H3
#  24                  Buffer_P1         A4
#  25                  Buffer_P1         B4
#  26                  Buffer_P1         C4
#  27                  Buffer_P1         D4
#  28                  Buffer_P1         E4
#  29                  Buffer_P1         F4
#  ..                        ...        ...
#  66                  Buffer_P3         C9
#  67                  Buffer_P3         D9
#  68                  Buffer_P3         E9
#  69                  Buffer_P3         F9
#  70                  Buffer_P3         G9
#  71                  Buffer_P3         H9
#  72                  Buffer_P3        A10
#  73                  Buffer_P3        B10
#  74                  Buffer_P3        C10
#  75                  Buffer_P3        D10
#  76                  Buffer_P3        E10
#  77                  Buffer_P3        F10
#  78                  Buffer_P3        G10
#  79                  Buffer_P3        H10
#  80                  Buffer_P3        A11
#  81                  Buffer_P3        B11
#  82                  Buffer_P3        C11
#  83                  Buffer_P3        D11
#  84                  Buffer_P3        E11
#  85                  Buffer_P3        F11
#  86                  Buffer_P3        G11
#  87                  Buffer_P3        H11
#  88                  Buffer_P3        A12
#  89                  Buffer_P3        B12
#  90                  Buffer_P3        C12
#  91                  Buffer_P3        D12
#  92                  Buffer_P3        E12
#  93                  Buffer_P3        F12
#  94                  Buffer_P3        G12
#  95                  Buffer_P3        H12
#
#  [96 rows x 2 columns]}

# %%
dfs=list(tidy_files.values()) # create list of tidy dataframes
dfs_merged=reduce(lambda left,right: pd.merge(left,right, on="well_id_96"), dfs) # merge all dataframes together on well_id
dfs_merged.to_csv("{}/metadata.csv".format(path_to_plates))
dfs_merged
# Out:
#     cell_number well_id_96 lonza_nucleofection_buffer
# 0       1000000         A1                  Buffer_P1
# 1       1000000         B1                  Buffer_P1
# 2       1000000         C1                  Buffer_P1
# 3       1000000         D1                  Buffer_P1
# 4       1000000         E1                  Buffer_P1
# 5       1000000         F1                  Buffer_P1
# 6       1000000         G1                  Buffer_P1
# 7       1000000         H1                  Buffer_P1
# 8       1000000         A2                  Buffer_P1
# 9       1000000         B2                  Buffer_P1
# 10      1000000         C2                  Buffer_P1
# 11      1000000         D2                  Buffer_P1
# 12      1000000         E2                  Buffer_P1
# 13      1000000         F2                  Buffer_P1
# 14      1000000         G2                  Buffer_P1
# 15      1000000         H2                  Buffer_P1
# 16      1000000         A3                  Buffer_P1
# 17      1000000         B3                  Buffer_P1
# 18      1000000         C3                  Buffer_P1
# 19      1000000         D3                  Buffer_P1
# 20      1000000         E3                  Buffer_P1
# 21      1000000         F3                  Buffer_P1
# 22      1000000         G3                  Buffer_P1
# 23      1000000         H3                  Buffer_P1
# 24      1000000         A4                  Buffer_P1
# 25      1000000         B4                  Buffer_P1
# 26      1000000         C4                  Buffer_P1
# 27      1000000         D4                  Buffer_P1
# 28      1000000         E4                  Buffer_P1
# 29      1000000         F4                  Buffer_P1
# ..          ...        ...                        ...
# 66      1000000         C9                  Buffer_P3
# 67      1000000         D9                  Buffer_P3
# 68      1000000         E9                  Buffer_P3
# 69      1000000         F9                  Buffer_P3
# 70      1000000         G9                  Buffer_P3
# 71      1000000         H9                  Buffer_P3
# 72      1000000        A10                  Buffer_P3
# 73      1000000        B10                  Buffer_P3
# 74      1000000        C10                  Buffer_P3
# 75      1000000        D10                  Buffer_P3
# 76      1000000        E10                  Buffer_P3
# 77      1000000        F10                  Buffer_P3
# 78      1000000        G10                  Buffer_P3
# 79      1000000        H10                  Buffer_P3
# 80      1000000        A11                  Buffer_P3
# 81      1000000        B11                  Buffer_P3
# 82      1000000        C11                  Buffer_P3
# 83      1000000        D11                  Buffer_P3
# 84      1000000        E11                  Buffer_P3
# 85      1000000        F11                  Buffer_P3
# 86      1000000        G11                  Buffer_P3
# 87      1000000        H11                  Buffer_P3
# 88      1000000        A12                  Buffer_P3
# 89      1000000        B12                  Buffer_P3
# 90      1000000        C12                  Buffer_P3
# 91      1000000        D12                  Buffer_P3
# 92      1000000        E12                  Buffer_P3
# 93      1000000        F12                  Buffer_P3
# 94      1000000        G12                  Buffer_P3
# 95      1000000        H12                  Buffer_P3
#
# [96 rows x 3 columns]

# %%
path_to_coords='/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/coord_maps'
path_to_coords
# Out:
# '/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/coord_maps'

# %%
all_coords=glob.glob("{}/*.csv".format(path_to_coords))
all_coords
# Out:
# ['/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/coord_maps/coord1_384.csv',
#  '/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/coord_maps/coord2_384.csv']

# %%
path_to_i7_384='/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/i7_index_384'
path_to_i5_384='/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/i5_index_384'

# %%
all_i7_index_384=glob.glob("{}/*.csv".format(path_to_i7_384))
all_i5_index_384=glob.glob("{}/*.csv".format(path_to_i5_384))
all_i5_index_384
# Out:
# ['/Users/giana.cirolia/Desktop/Nucleofection_Pipelne_Code/i5_index_384/i5_index_384.csv']

# %%
dict_all_i7_index_384={}

for file in all_i7_index_384:
    file_name=os.path.splitext(os.path.basename(file))[0]
    df=pd.read_csv(file)
    dict_all_i7_index_384[file_name]=df

dict_all_i7_index_384
# Out:
# {'i7_index_384':     i7_index_384 I7_Index_ID i7_index_sequence
#  0             A1    i7-00001          CTGATCGT
#  1             A2    i7-00002          ACTCTCGA
#  2             A3    i7-00003          TGAGCTAG
#  3             A4    i7-00004          GAGACGAT
#  4             A5    i7-00005          CTTGTCGA
#  5             A6    i7-00006          TTCCAAGG
#  6             A7    i7-00049          CGCATGAT
#  7             A8    i7-00008          ACGGAACA
#  8             A9    i7-00009          CGGCTAAT
#  9            A10    i7-00010          ATCGATCG
#  10           A11    i7-00011          GCAAGATC
#  11           A12    i7-00012          GCTATCCT
#  12           A13    i7-00013          TACGCTAC
#  13           A14    i7-00014          TGGACTCT
#  14           A15    i7-00015          AGAGTAGC
#  15           A16    i7-00016          ATCCAGAG
#  16           A17    i7-00017          GACGATCT
#  17           A18    i7-00018          AACTGAGC
#  18           A19    i7-00019          CTTAGGAC
#  19           A20    i7-00020          GTGCCATA
#  20           A21    i7-00021          GAATCCGA
#  21           A22    i7-00022          TCGCTGTT
#  22           A23    i7-00023          TTCGTTGG
#  23           A24    i7-00024          AAGCACTG
#  24            B1    i7-00025          CCTTGATC
#  25            B2    i7-00026          GTCGAAGA
#  26            B3    i7-00027          ACCACGAT
#  27            B4    i7-00028          GATTACCG
#  28            B5    i7-00029          GCACAACT
#  29            B6    i7-00030          GCGTCATT
#  ..           ...         ...               ...
#  354          O19    i7-00355          GTCCTAAG
#  355          O20    i7-00356          CCGACTAT
#  356          O21    i7-00357          TTGGTCTC
#  357          O22    i7-00358          GCCTTGTT
#  358          O23    i7-00359          GATACTGG
#  359          O24    i7-00360          ATTCGAGG
#  360           P1    i7-00361          GTCAGTTG
#  361           P2    i7-00362          GTAGAGCA
#  362           P3    i7-00363          ACGTGATG
#  363           P4    i7-00364          TAAGTGGC
#  364           P5    i7-00365          TGTGAAGC
#  365           P6    i7-00366          CATTCGGT
#  366           P7    i7-00367          TTGGTGAG
#  367           P8    i7-00368          CAGTTCTG
#  368           P9    i7-00369          AGGCTTCT
#  369          P10    i7-00370          GAATCGTG
#  370          P11    i7-00371          ACCAGCTT
#  371          P12    i7-00372          CTCATTGC
#  372          P13    i7-00373          CGATAGAG
#  373          P14    i7-00374          TGGAGAGT
#  374          P15    i7-00375          GTATGCTG
#  375          P16    i7-00376          CTGGAGTA
#  376          P17    i7-00377          AATGCCTC
#  377          P18    i7-00378          TGAGGTGT
#  378          P19    i7-00379          ACATTGCG
#  379          P20    i7-00380          TCTCTAGG
#  380          P21    i7-00381          CGCTAGTA
#  381          P22    i7-00382          AATGGACG
#  382          P23    i7-00383          GATAGCGA
#  383          P24    i7-00384          CGACCATT
#
#  [384 rows x 3 columns]}

# %%
dict_all_i5_index_384={}

for file in all_i5_index_384:
    file_name=os.path.splitext(os.path.basename(file))[0]
    df=pd.read_csv(file)
    dict_all_i5_index_384[file_name]=df
dict_all_i5_index_384['i5_index_384']
# Out:
#     i5_index_384 i5_index_ID i5_index_sequence
# 0             A1    i5-00001          ACGATCAG
# 1             A2    i5-00002          TCGAGAGT
# 2             A3    i5-00003          CTAGCTCA
# 3             A4    i5-00004          ATCGTCTC
# 4             A5    i5-00005          TCGACAAG
# 5             A6    i5-00006          CCTTGGAA
# 6             A7    i5-00049          ATCATGCG
# 7             A8    i5-00008          TGTTCCGT
# 8             A9    i5-00009          ATTAGCCG
# 9            A10    i5-00010          CGATCGAT
# 10           A11    i5-00011          GATCTTGC
# 11           A12    i5-00012          AGGATAGC
# 12           A13    i5-00013          GTAGCGTA
# 13           A14    i5-00014          AGAGTCCA
# 14           A15    i5-00015          GCTACTCT
# 15           A16    i5-00016          CTCTGGAT
# 16           A17    i5-00017          AGATCGTC
# 17           A18    i5-00018          GCTCAGTT
# 18           A19    i5-00019          GTCCTAAG
# 19           A20    i5-00020          TATGGCAC
# 20           A21    i5-00021          TCGGATTC
# 21           A22    i5-00022          AACAGCGA
# 22           A23    i5-00023          CCAACGAA
# 23           A24    i5-00024          CAGTGCTT
# 24            B1    i5-00025          GATCAAGG
# 25            B2    i5-00026          TCTTCGAC
# 26            B3    i5-00027          ATCGTGGT
# 27            B4    i5-00028          CGGTAATC
# 28            B5    i5-00029          AGTTGTGC
# 29            B6    i5-00030          AATGACGC
# ..           ...         ...               ...
# 354          O19    i5-00355          CTTAGGAC
# 355          O20    i5-00356          ATAGTCGG
# 356          O21    i5-00357          GAGACCAA
# 357          O22    i5-00358          AACAAGGC
# 358          O23    i5-00359          CCAGTATC
# 359          O24    i5-00360          CCTCGAAT
# 360           P1    i5-00361          CAACTGAC
# 361           P2    i5-00362          TGCTCTAC
# 362           P3    i5-00363          CATCACGT
# 363           P4    i5-00364          GCCACTTA
# 364           P5    i5-00365          GCTTCACA
# 365           P6    i5-00366          ACCGAATG
# 366           P7    i5-00367          CTCACCAA
# 367           P8    i5-00368          CAGAACTG
# 368           P9    i5-00369          AGAAGCCT
# 369          P10    i5-00370          CACGATTC
# 370          P11    i5-00371          AAGCTGGT
# 371          P12    i5-00372          GCAATGAG
# 372          P13    i5-00373          CTCTATCG
# 373          P14    i5-00374          ACTCTCCA
# 374          P15    i5-00375          CAGCATAC
# 375          P16    i5-00376          TACTCCAG
# 376          P17    i5-00377          GAGGCATT
# 377          P18    i5-00378          ACACCTCA
# 378          P19    i5-00379          CGCAATGT
# 379          P20    i5-00380          CCTAGAGA
# 380          P21    i5-00381          TACTAGCG
# 381          P22    i5-00382          CGTCCATT
# 382          P23    i5-00383          TCGCTATC
# 383          P24    i5-00384          AATGGTCG
#
# [384 rows x 3 columns]

# %%
dict_of_coords={}

for file in all_coords:
    file_name=os.path.splitext(os.path.basename(file))[0]
    df=pd.read_csv(file)
    dict_of_coords[file_name]=df

dict_of_coords
# Out:
# {'coord1_384':    well_id_96 coord1_384
#  0          A1         A1
#  1          A2         A3
#  2          A3         A5
#  3          A4         A7
#  4          A5         A9
#  5          A6        A11
#  6          A7        A13
#  7          A8        A15
#  8          A9        A17
#  9         A10        A19
#  10        A11        A21
#  11        A12        A23
#  12         B1         C1
#  13         B2         C3
#  14         B3         C5
#  15         B4         C7
#  16         B5         C9
#  17         B6        C11
#  18         B7        C13
#  19         B8        C15
#  20         B9        C17
#  21        B10        C19
#  22        B11        C21
#  23        B12        C23
#  24         C1         E1
#  25         C2         E3
#  26         C3         E5
#  27         C4         E7
#  28         C5         E9
#  29         C6        E11
#  ..        ...        ...
#  66         F7        K13
#  67         F8        K15
#  68         F9        K17
#  69        F10        K19
#  70        F11        K21
#  71        F12        K23
#  72         G1         M1
#  73         G2         M3
#  74         G3         M5
#  75         G4         M7
#  76         G5         M9
#  77         G6        M11
#  78         G7        M13
#  79         G8        M15
#  80         G9        M17
#  81        G10        M19
#  82        G11        M21
#  83        G12        M23
#  84         H1         O1
#  85         H2         O3
#  86         H3         O5
#  87         H4         O7
#  88         H5         O9
#  89         H6        O11
#  90         H7        O13
#  91         H8        O15
#  92         H9        O17
#  93        H10        O19
#  94        H11        O21
#  95        H12        O23
#
#  [96 rows x 2 columns], 'coord2_384':    well_id_96 coord2_384
#  0          A1         A2
#  1          A2         A4
#  2          A3         A6
#  3          A4         A8
#  4          A5        A10
#  5          A6        A12
#  6          A7        A14
#  7          A8        A16
#  8          A9        A18
#  9         A10        A20
#  10        A11        A22
#  11        A12        A24
#  12         B1         C2
#  13         B2         C4
#  14         B3         C6
#  15         B4         C8
#  16         B5        C10
#  17         B6        C12
#  18         B7        C14
#  19         B8        C16
#  20         B9        C18
#  21        B10        C20
#  22        B11        C22
#  23        B12        C24
#  24         C1         E2
#  25         C2         E4
#  26         C3         E6
#  27         C4         E8
#  28         C5        E10
#  29         C6        E12
#  ..        ...        ...
#  66         F7        K14
#  67         F8        K16
#  68         F9        K18
#  69        F10        K20
#  70        F11        K22
#  71        F12        K24
#  72         G1         M2
#  73         G2         M4
#  74         G3         M6
#  75         G4         M8
#  76         G5        M10
#  77         G6        M12
#  78         G7        M14
#  79         G8        M16
#  80         G9        M18
#  81        G10        M20
#  82        G11        M22
#  83        G12        M24
#  84         H1         O2
#  85         H2         O4
#  86         H3         O6
#  87         H4         O8
#  88         H5        O10
#  89         H6        O12
#  90         H7        O14
#  91         H8        O16
#  92         H9        O18
#  93        H10        O20
#  94        H11        O22
#  95        H12        O24
#
#  [96 rows x 2 columns]}

# %%
i7=dict_all_i7_index_384["i7_index_384"]
coord1=dict_of_coords["coord1_384"]
coord1_i7_merged=coord1.merge(i7, left_on="coord1_384", right_on="i7_index_384")
coord1_i7_merged
# Out:
#    well_id_96 coord1_384 i7_index_384 I7_Index_ID i7_index_sequence
# 0          A1         A1           A1    i7-00001          CTGATCGT
# 1          A2         A3           A3    i7-00003          TGAGCTAG
# 2          A3         A5           A5    i7-00005          CTTGTCGA
# 3          A4         A7           A7    i7-00049          CGCATGAT
# 4          A5         A9           A9    i7-00009          CGGCTAAT
# 5          A6        A11          A11    i7-00011          GCAAGATC
# 6          A7        A13          A13    i7-00013          TACGCTAC
# 7          A8        A15          A15    i7-00015          AGAGTAGC
# 8          A9        A17          A17    i7-00017          GACGATCT
# 9         A10        A19          A19    i7-00019          CTTAGGAC
# 10        A11        A21          A21    i7-00021          GAATCCGA
# 11        A12        A23          A23    i7-00023          TTCGTTGG
# 12         B1         C1           C1    i7-00049          GAGCAGTA
# 13         B2         C3           C3    i7-00051          TTGCGAAG
# 14         B3         C5           C5    i7-00053          TGGCATGT
# 15         B4         C7           C7    i7-00055          CATACCAC
# 16         B5         C9           C9    i7-00057          ATGACGTC
# 17         B6        C11          C11    i7-00059          AGTGGATC
# 18         B7        C13          C13    i7-00061          TGGTAGCT
# 19         B8        C15          C15    i7-00063          GATGTGTG
# 20         B9        C17          C17    i7-00065          CGCTCTAT
# 21        B10        C19          C19    i7-00067          AACGTCTG
# 22        B11        C21          C21    i7-00069          CAGTCCAA
# 23        B12        C23          C23    i7-00071          CAATGTGG
# 24         C1         E1           E1    i7-00097          GCCTATCA
# 25         C2         E3           E3    i7-00099          AGTCTCAC
# 26         C3         E5           E5    i7-00101          TGTACCGT
# 27         C4         E7           E7    i7-00103          CACGTTGT
# 28         C5         E9           E9    i7-00105          CTACTTGG
# 29         C6        E11          E11    i7-00107          TCCTACCT
# ..        ...        ...          ...         ...               ...
# 66         F7        K13          K13    i7-00253          GTAGCATC
# 67         F8        K15          K15    i7-00255          AGGATGGT
# 68         F9        K17          K17    i7-00257          GCGTTCTA
# 69        F10        K19          K19    i7-00259          TTAGGTCG
# 70        F11        K21          K21    i7-00261          TTCAGCCT
# 71        F12        K23          K23    i7-00263          CAGGTATC
# 72         G1         M1           M1    i7-00289          CATTGCCT
# 73         G2         M3           M3    i7-00291          TCCGTATG
# 74         G3         M5           M5    i7-00293          GTCGGTAA
# 75         G4         M7           M7    i7-00295          AGAAGCGT
# 76         G5         M9           M9    i7-00297          CTAGGCAT
# 77         G6        M11          M11    i7-00299          GAGGACTT
# 78         G7        M13          M13    i7-00301          TCTAACGC
# 79         G8        M15          M15    i7-00303          ATCGGTGT
# 80         G9        M17          M17    i7-00305          GTCTCCTT
# 81        G10        M19          M19    i7-00307          CGGATTGA
# 82        G11        M21          M21    i7-00309          TACATCGG
# 83        G12        M23          M23    i7-00311          ACTCGTTG
# 84         H1         O1           O1    i7-00337          GACTTAGG
# 85         H2         O3           O3    i7-00339          TACCAGGA
# 86         H3         O5           O5    i7-00341          GAAGAGGT
# 87         H4         O7           O7    i7-00343          AGGAGGAA
# 88         H5         O9           O9    i7-00345          GAGATGTC
# 89         H6        O11          O11    i7-00347          CTATCGCA
# 90         H7        O13          O13    i7-00349          GAACGCTT
# 91         H8        O15          O15    i7-00351          ATGGTTGC
# 92         H9        O17          O17    i7-00353          GATGCACT
# 93        H10        O19          O19    i7-00355          GTCCTAAG
# 94        H11        O21          O21    i7-00357          TTGGTCTC
# 95        H12        O23          O23    i7-00359          GATACTGG
#
# [96 rows x 5 columns]

# %%
new=coord1_i7_merged.merge(dfs_merged, left_on="well_id_96", right_on="well_id_96")
new
# Out:
#    well_id_96 coord1_384 i7_index_384 I7_Index_ID i7_index_sequence  \
# 0          A1         A1           A1    i7-00001          CTGATCGT
# 1          A2         A3           A3    i7-00003          TGAGCTAG
# 2          A3         A5           A5    i7-00005          CTTGTCGA
# 3          A4         A7           A7    i7-00049          CGCATGAT
# 4          A5         A9           A9    i7-00009          CGGCTAAT
# 5          A6        A11          A11    i7-00011          GCAAGATC
# 6          A7        A13          A13    i7-00013          TACGCTAC
# 7          A8        A15          A15    i7-00015          AGAGTAGC
# 8          A9        A17          A17    i7-00017          GACGATCT
# 9         A10        A19          A19    i7-00019          CTTAGGAC
# 10        A11        A21          A21    i7-00021          GAATCCGA
# 11        A12        A23          A23    i7-00023          TTCGTTGG
# 12         B1         C1           C1    i7-00049          GAGCAGTA
# 13         B2         C3           C3    i7-00051          TTGCGAAG
# 14         B3         C5           C5    i7-00053          TGGCATGT
# 15         B4         C7           C7    i7-00055          CATACCAC
# 16         B5         C9           C9    i7-00057          ATGACGTC
# 17         B6        C11          C11    i7-00059          AGTGGATC
# 18         B7        C13          C13    i7-00061          TGGTAGCT
# 19         B8        C15          C15    i7-00063          GATGTGTG
# 20         B9        C17          C17    i7-00065          CGCTCTAT
# 21        B10        C19          C19    i7-00067          AACGTCTG
# 22        B11        C21          C21    i7-00069          CAGTCCAA
# 23        B12        C23          C23    i7-00071          CAATGTGG
# 24         C1         E1           E1    i7-00097          GCCTATCA
# 25         C2         E3           E3    i7-00099          AGTCTCAC
# 26         C3         E5           E5    i7-00101          TGTACCGT
# 27         C4         E7           E7    i7-00103          CACGTTGT
# 28         C5         E9           E9    i7-00105          CTACTTGG
# 29         C6        E11          E11    i7-00107          TCCTACCT
# ..        ...        ...          ...         ...               ...
# 66         F7        K13          K13    i7-00253          GTAGCATC
# 67         F8        K15          K15    i7-00255          AGGATGGT
# 68         F9        K17          K17    i7-00257          GCGTTCTA
# 69        F10        K19          K19    i7-00259          TTAGGTCG
# 70        F11        K21          K21    i7-00261          TTCAGCCT
# 71        F12        K23          K23    i7-00263          CAGGTATC
# 72         G1         M1           M1    i7-00289          CATTGCCT
# 73         G2         M3           M3    i7-00291          TCCGTATG
# 74         G3         M5           M5    i7-00293          GTCGGTAA
# 75         G4         M7           M7    i7-00295          AGAAGCGT
# 76         G5         M9           M9    i7-00297          CTAGGCAT
# 77         G6        M11          M11    i7-00299          GAGGACTT
# 78         G7        M13          M13    i7-00301          TCTAACGC
# 79         G8        M15          M15    i7-00303          ATCGGTGT
# 80         G9        M17          M17    i7-00305          GTCTCCTT
# 81        G10        M19          M19    i7-00307          CGGATTGA
# 82        G11        M21          M21    i7-00309          TACATCGG
# 83        G12        M23          M23    i7-00311          ACTCGTTG
# 84         H1         O1           O1    i7-00337          GACTTAGG
# 85         H2         O3           O3    i7-00339          TACCAGGA
# 86         H3         O5           O5    i7-00341          GAAGAGGT
# 87         H4         O7           O7    i7-00343          AGGAGGAA
# 88         H5         O9           O9    i7-00345          GAGATGTC
# 89         H6        O11          O11    i7-00347          CTATCGCA
# 90         H7        O13          O13    i7-00349          GAACGCTT
# 91         H8        O15          O15    i7-00351          ATGGTTGC
# 92         H9        O17          O17    i7-00353          GATGCACT
# 93        H10        O19          O19    i7-00355          GTCCTAAG
# 94        H11        O21          O21    i7-00357          TTGGTCTC
# 95        H12        O23          O23    i7-00359          GATACTGG
#
#     cell_number lonza_nucleofection_buffer
# 0       1000000                  Buffer_P1
# 1       1000000                  Buffer_P1
# 2       1000000                  Buffer_P1
# 3       1000000                  Buffer_P1
# 4       1000000                  Buffer_P2
# 5       1000000                  Buffer_P2
# 6       1000000                  Buffer_P2
# 7       1000000                  Buffer_P2
# 8       1000000                  Buffer_P3
# 9       1000000                  Buffer_P3
# 10      1000000                  Buffer_P3
# 11      1000000                  Buffer_P3
# 12      1000000                  Buffer_P1
# 13      1000000                  Buffer_P1
# 14      1000000                  Buffer_P1
# 15      1000000                  Buffer_P1
# 16      1000000                  Buffer_P2
# 17      1000000                  Buffer_P2
# 18      1000000                  Buffer_P2
# 19      1000000                  Buffer_P2
# 20      1000000                  Buffer_P3
# 21      1000000                  Buffer_P3
# 22      1000000                  Buffer_P3
# 23      1000000                  Buffer_P3
# 24      1000000                  Buffer_P1
# 25      1000000                  Buffer_P1
# 26      1000000                  Buffer_P1
# 27      1000000                  Buffer_P1
# 28      1000000                  Buffer_P2
# 29      1000000                  Buffer_P2
# ..          ...                        ...
# 66      1000000                  Buffer_P2
# 67      1000000                  Buffer_P2
# 68      1000000                  Buffer_P3
# 69      1000000                  Buffer_P3
# 70      1000000                  Buffer_P3
# 71      1000000                  Buffer_P3
# 72      1000000                  Buffer_P1
# 73      1000000                  Buffer_P1
# 74      1000000                  Buffer_P1
# 75      1000000                  Buffer_P1
# 76      1000000                  Buffer_P2
# 77      1000000                  Buffer_P2
# 78      1000000                  Buffer_P2
# 79      1000000                  Buffer_P2
# 80      1000000                  Buffer_P3
# 81      1000000                  Buffer_P3
# 82      1000000                  Buffer_P3
# 83      1000000                  Buffer_P3
# 84      1000000                  Buffer_P1
# 85      1000000                  Buffer_P1
# 86      1000000                  Buffer_P1
# 87      1000000                  Buffer_P1
# 88      1000000                  Buffer_P2
# 89      1000000                  Buffer_P2
# 90      1000000                  Buffer_P2
# 91      1000000                  Buffer_P2
# 92      1000000                  Buffer_P3
# 93      1000000                  Buffer_P3
# 94      1000000                  Buffer_P3
# 95      1000000                  Buffer_P3
#
# [96 rows x 7 columns]
